# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#EDA" data-toc-modified-id="EDA-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>EDA</a></span></li><li><span><a href="#Подготовка-признаков" data-toc-modified-id="Подготовка-признаков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Подготовка признаков</a></span></li><li><span><a href="#Разделение-данных-на-выборки" data-toc-modified-id="Разделение-данных-на-выборки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Разделение данных на выборки</a></span><ul class="toc-item"><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Исследование-моделей" data-toc-modified-id="Исследование-моделей-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Исследование моделей</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Настройка-гиперпараметра-class_weight-=-'balanced'" data-toc-modified-id="Настройка-гиперпараметра-class_weight-=-'balanced'-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Настройка гиперпараметра class_weight = 'balanced'</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Увеличение-обучающей-выборки" data-toc-modified-id="Увеличение-обучающей-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение обучающей выборки</a></span><ul class="toc-item"><li><span><a href="#Дерево-принятия-решений---увеличенная-обучающая-выборка" data-toc-modified-id="Дерево-принятия-решений---увеличенная-обучающая-выборка-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Дерево принятия решений - увеличенная обучающая выборка</a></span></li><li><span><a href="#Случайный-лес---увеличенная-обучающая-выборка" data-toc-modified-id="Случайный-лес---увеличенная-обучающая-выборка-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Случайный лес - увеличенная обучающая выборка</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из Банка стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# На основе исторических данных о поведении клиентов и расторжении договоров с Банком необходимо спрогнозировать, уйдёт клиент из Банка в ближайшее время или нет.
#
# **Задача проекта:**
# * построить модель с предельно большим значением *F1*-меры
# * довести метрику до 0.59
# * проверить *F1*-меру на тестовой выборке
# * измерить *AUC-ROC*, сравнить её значение с *F1*-мерой

# %% [markdown]
# ## Подготовка данных

# %%
# загружем библиотеки и подготавливаем рабочее пространство

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils import shuffle

from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.inspection import permutation_importance

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
# загружаем файл,
# читаем первые 5 строк,
# выводим общую информацию о файле
data = pd.read_csv('/datasets/Churn.csv')
display(data.head(2))
display(data.info())
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0      0.00              1          1               1
# 1     1.0  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
# ...

# %%
# проверяем наличие пропусков
print('Количество пропущенных значений:\n', data.isnull().sum())
# Out:
# Количество пропущенных значений:
#  RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %%
# проверяем распределение уникальных значений признака Tenure
data['Tenure'].value_counts()
# Out:
# 1.0     952
# 2.0     950
# 8.0     933
# 3.0     928
# 5.0     927
# 7.0     925
# 4.0     885
# 9.0     882
# 6.0     881
# 10.0    446
# 0.0     382
# Name: Tenure, dtype: int64

# %%
# проверяем объекты с пропущенным значением по признаку Tenure
tenure_nan = data[data.isna().any(axis=1)]
display(tenure_nan.sort_values(by='CustomerId'))
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 3416       3417    15565806    Toosey          532    France    Male   38
# 424         425    15566111     Estes          596    France    Male   39
# 981         982    15566156  Franklin          749   Germany  Female   44
# 799         800    15567367       Tao          601   Germany  Female   42
# 597         598    15567446   Coffman          646   Germany    Male   39
# ...         ...         ...       ...          ...       ...     ...  ...
# 7053       7054    15815271   Ritchie          755   Germany    Male   43
# 7122       7123    15815443        Lo          527     Spain  Female   46
# 2658       2659    15815490     Cocci          670   Germany    Male   40
# 6640       6641    15815615      Kung          681    France    Male   36
# 5502       5503    15815690  Akabueze          614     Spain  Female   40
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# проверяем наличие дубликатов
print('Количество дубликатов:\n', data.duplicated().sum())
# Out:
# Количество дубликатов:
#  0

# %% [markdown]
# ### Выводы
# * Таблица содержит 10 000 записей и 14 колонок.
# * Названия колонок и запись данных единообразны.
# * Данные записаны в ожидаемых форматах.
# * Только признак Tenure содержит пропущенные значения - 909 значений.
# * Признак представлен цельночисленными значениями от 0 до 10.
# * Визуальный анализ объектов с пропущенным значением в признаке Tenure не выявил закономерностей.
# * Дубликаты в данных отсутствуют.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### EDA

# %%
# проверяем распределение данных целевой переменной Exited - баланс классов
sns.countplot(data=data, x='Exited')
plt.title('Распределение данных целевой переменной', fontsize=12);
print('Доля ушедших клиентов:', data.Exited.mean())
# Out:
# Доля ушедших клиентов: 0.2037

# %% [markdown]
# **Выводы по графику:**
# * В датасете присутствует дисбаланс классов - доля ушедших составляет 20%

# %%
# проверяем уникальность записей CustomerId
data.CustomerId.nunique()
# Out:
# 10000

# %%
# проверяем консистентность данных CustomerId
fig, axes = plt.subplots(1, 1, figsize=(15, 5))
g = sns.histplot(data=data, x="CustomerId", bins=3000)
g.set_title('Распределение данных CustomerId');

# %% [markdown]
# **Выводы по данным и графику:**
# * датасет состоит из 10 000 объектов с уникальными Id номерами
# * Id номера идут не попорядку, группами до 9 номеров, с пробелами

# %%
# проверяем кол-во уникальных записей по параметру Geography
print("Количество клиентов в странах:\n", data.groupby('Geography')['CustomerId'].count())
ax = sns.countplot(x='Geography', data = data)
ax.set(xlabel='страна', ylabel='кол-во клиентов')
plt.title('Распределение клиентов по странам', fontsize=12);
# Out:
# Количество клиентов в странах:
#  Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: CustomerId, dtype: int64

# %%
# проверяем доли ушедших и оставшихся клиентов в разбивке по странам
data_geo=(data.groupby('Geography')['Exited'].value_counts(normalize=True).round(2).to_frame('perc').reset_index())
from matplotlib.ticker import PercentFormatter
p=sns.catplot(x='Geography', y='perc', col='Exited', kind='bar', data=data_geo)
plt.suptitle('Доли ушедших клиентов по странам', fontsize=12, y=1.08)
p.set(xlabel='страна', ylabel='доля клиентов')
for ax in p.axes.flat:
    ax.yaxis.set_major_formatter(PercentFormatter(1))

# %% [markdown]
# **Выводы по данным и графикам:**
# * клиенты из датасета распределены между тремя европейскими странами:
# >
# > 50% - Франция
# >
# > 25% - Германия
# >
# > 25% - Испания
# >
# * самый большой отток произошел в Германии:
# >
# > Франция - отток составил 15%
# >
# > Германия - отток составил 30%
# >
# > Испания - отток составил 15%
# >

# %%
# изучаем распределение данных CreditScore с разбивкой по целевой переменной
fig, axes = plt.subplots(1, 1, figsize=(15, 5))
g = sns.histplot(data=data, x="CreditScore", hue="Exited", multiple="stack", bins=70)
g.set_title('Распределение данных CreditScore с разбивкой по целевой переменной');

# %%
# выводим стат данные по параметру CreditScore
data['CreditScore'].describe()
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: CreditScore, dtype: float64

# %%
# делаем выборку данных с максимальным скором
display(data[data['CreditScore'] == 850])
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 4             5    15737888   Mitchell          850     Spain  Female   43
# 38           39    15717426  Armstrong          850    France    Male   36
# 180         181    15716334     Rozier          850     Spain  Female   45
# 200         201    15604482  Chiemezie          850     Spain    Male   30
# 223         224    15733247  Stevenson          850    France    Male   33
# ...         ...         ...        ...          ...       ...     ...  ...
# 9581       9582    15709256     Glover          850    France  Female   28
# 9646       9647    15603111       Muir          850     Spain    Male   71
# 9688       9689    15730579       Ward          850    France    Male   68
# 9931       9932    15647800      Greco          850    France  Female   34
# 9949       9950    15798615        Wan          850    France  Female   47
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# проверяем попарное распределение данных в параметрах с максимальным скором
g = sns.pairplot(data=data[data['CreditScore'] == 850]\
                 , vars=['Age', 'Balance', 'EstimatedSalary', 'NumOfProducts', 'IsActiveMember'])
g.fig.suptitle('Попарное рапределение данных в параметрах с максимальным скором'\
               , y=1.08, fontsize=18);

# %% [markdown]
# **Выводы по данным и графику:**
# * кредитный скор распределен в промежутке значений от 96.7 до 850
# * практически все клиенты, получившие скор от 96.7 до 410, ушли из банка
# * данные имеют склонное к нормальному распределение
# * выбросы отсутствуют, значения среднего и медианы близки
# * половина клиентов получили скор до 652
# * существует всплеск по максимальному значению скора = 850
# * попарное распределение данных в выборке с максимальным скором не выявило линейных зависимостей
# * доля ушедших приблизительно сохраняется на одном уровне во всех скоринговых группах

# %%
# проверяем баланс полов
sns.countplot(data=data, x='Gender')
plt.title('Распределение клиентов в разрезе гендера ', fontsize=12);
print("Распределение по гендеру:\n", data.groupby('Gender')['CustomerId'].count())
# Out:
# Распределение по гендеру:
#  Gender
# Female    4543
# Male      5457
# Name: CustomerId, dtype: int64

# %%
# проверяем баланс полов по странам
sns.catplot(x='Gender', col='Geography', kind='count', data=data, hue='Exited')
plt.suptitle('Распределение клиентов в разрезе гендера по странам с разбивкой по целевой переменной'\
          , fontsize=12, y=1.08);

# %% [markdown]
# **Выводы по графикам:**
# * общее соотношение полов в выборке составляет 55% (мужчины) и 45% (женщины)
# * общий тренд в разбивке по странам сохраняется
# * среди ушедших во всех странах преобладают женщины

# %%
# изучаем распределение данных Age с разбивкой по целевой переменной
fig, axes = plt.subplots(1, 1, figsize=(15, 5))
g = sns.histplot(data=data, x="Age", hue="Exited", multiple="stack", bins=75)
g.set_title('Распределение данных Age с разбивкой по целевой переменной');

# %%
# выводим стат данные по параметру Age
data['Age'].describe()
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64

# %% [markdown]
# **выводы по данным и графику:**
# * данные по возрасту распределены в диапазоне от 18 до 92 лет
# * данные скошены вправо, имеют выбросы
# * средний возвраст клиента - 39 лет
# * 75% клиентов находятся в возрасте до 44 лет
# * средний возраст ушедшего клиента - 45 лет

# %%
# изучаем распределение данных Balance с разбивкой по целевой переменной
fig, axes = plt.subplots(1, 1, figsize=(15, 5))
g = sns.histplot(data=data, x="Balance", hue="Exited", multiple="stack", bins=90)
g.set_title('Распределение данных Balance с разбивкой по целевой переменной');

# %%
# изучаем распределение данных с не нулевым балансом с разбивкой по целевой переменной
fig, axes = plt.subplots(1, 1, figsize=(15, 5))
g = sns.histplot(data=data[data['Balance'] != 0], x="Balance", hue="Exited", multiple="stack", bins=90)
g.set_title('Распределение данных с не нулевым балансом с разбивкой по целевой переменной');

# %%
# выводим стат данные по параметру Balance
data['Balance'].describe()
# Out:
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: Balance, dtype: float64

# %% [markdown]
# **выводы по данным и графику:**
# * 35% клиентов имеют нулевой баланс с банком
# * данные с не нулевым балансом стремятся к нормальному распределению
# * 75% клиентов имеют баланс до 127 644
# * распределение ушедших клиентов имеет общий тренд

# %%
# изучаем распределение данных о количестве продуктов в разбивке по странам
ax = sns.countplot('NumOfProducts', data=data, hue='Geography')
ax.set(xlabel='кол-во продуктов', ylabel='кол-во клиентов')
plt.title('Количество продуктов по странам', fontsize=12);

# %%
# изучаем долю ушедших клиентов в зависимости от кол-ва продуктов с разбивкой по гендерам
ax = sns.catplot('NumOfProducts', 'Exited', hue='Gender', kind='point', data=data)
ax.set(xlabel='кол-во продуктов', ylabel='доля ушедших клиентов')
plt.title('Доля ушедших клиентов в продуктах', fontsize=12);

# %% [markdown]
# **Выводы по графикам:**
# * наиболее популярным форматом является обладание 1 - 2 банковскими продуктами
# * максимальное количество продуктов составляет 4
# * наименьший отток клиентов происходит среди владельцев 2-х продуктов
# * среди владельцев 4-х продуктов отток составляет 100%
# * тренды по гендерному распределению в оттоке сохраняются

# %%
# проверяем баланс владения кредитными картами
ax = sns.countplot(data=data, x='HasCrCard')
plt.title('Распределение клиентов в разрезе владения кредитной картой ', fontsize=12);
print("Распределение по владению:\n", data.groupby('HasCrCard')['CustomerId'].count())
# Out:
# Распределение по владению:
#  HasCrCard
# 0    2945
# 1    7055
# Name: CustomerId, dtype: int64

# %%
# изучаем распределение данных о владении кредитной картой в разбивке по странам
ax = sns.countplot('HasCrCard', data=data, hue='Geography')
ax.set(xlabel='владение картой', ylabel='кол-во клиентов')
plt.title('Владение картой по странам', fontsize=12);

# %%
# изучаем долю ушедших клиентов в зависимости от факта владения кредитной картой с разбивкой по гендерам
ax = sns.catplot('HasCrCard', 'Exited', hue='Gender', kind='point', data=data)
ax.set(xlabel='владение картой', ylabel='доля ушедших клиентов')
plt.title('Доля ушедших клиентов в зависимсоти от владения картой', fontsize=12);

# %% [markdown]
# **Выводы по графикам:**
# * 70% клиентов банка владеют кредитными картами
# * распределение данных по странам имеет общий тренд
# * % оттока у владеющих картой ниже
# * гендерное распределение имеет общий тренд

# %%
# проверяем распределение клиентов по кол-ву лет работы с банком
ax = sns.countplot(data=data, x='Tenure', hue='Exited')
plt.title('Распределение клиентов в разрезе кол-ва лет работы с банком ', fontsize=12)
ax.set(xlabel='кол-во лет работы с банком', ylabel='кол-во клиентов');

# %%
# проверяем распределение клиентов с отсутствующими данными по кол-ву лет работы с банком
# в разрезе стран, гендера и целевого признака
display(tenure_nan.groupby(['Geography', 'Gender', 'Exited'])['CustomerId'].count().reset_index())
# Out:
#    Geography  Gender  Exited  CustomerId
# 0     France  Female       0         178
# 1     France  Female       1          39
# 2     France    Male       0         209
# 3     France    Male       1          38
# 4    Germany  Female       0          71
# 5    Germany  Female       1          37
# 6    Germany    Male       0          82
# 7    Germany    Male       1          26
# 8      Spain  Female       0          79
# 9      Spain  Female       1          22
# 10     Spain    Male       0         107
# 11     Spain    Male       1          21

# %%
# выборочно проверяем ближайших соседей по CustomerId
display(data[data['CustomerId'].between(15566090, 15566140)].sort_values(by='CustomerId'))
display(data[data['CustomerId'].between(15567337, 15567387)].sort_values(by='CustomerId'))
# Out:
#       RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 912         913    15566091  Thomsen          545     Spain  Female   32
# 424         425    15566111    Estes          596    France    Male   39
# 9631       9632    15566139    Ts'ui          526    France  Female   37
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 912      4.0      0.00              1          1               0
# 424      NaN      0.00              1          1               0
# 9631     5.0  53573.18              1          1               0
#
#       EstimatedSalary  Exited
# 912          94739.20       0
# 424          48963.59       0
# 9631         62830.97       0
#       RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  \
# 9112       9113    15567339    Shaw          735    France    Male   73
# 799         800    15567367     Tao          601   Germany  Female   42
# ...

# %% [markdown]
# **Выводы по данным и графику:**
# * периоды взаимодействия клиента с банком определены 10 годами
# * крайние мминимум и максимум (0 и 10 лет) представлены равнозначными группами в среднем по 400 клиентов
# * группы 1 - 9 лет представлены по 900 - 1 000 клиентов
# * разделение на классы также достаточно монотонно
# * в группа 0 и 10 лет насчитывается по 100 ушедших клиентов
# * в группах 1 - 9 лет насчитывется в среднем по 200 клиентов
# * дополнительный анализ ближайших соседей по объектам с пропущенными значениями периода взаимодействия с банком не позволил выявить явные закономерности для принятия решения о логичной замене пропусков

# %%
# проверяем баланс по параметру IsActiveMember
ax = sns.countplot(data=data, x='IsActiveMember', hue='Exited')
plt.title('Распределение клиентов в разрезе активности', fontsize=12)
ax.set(xlabel='активность', ylabel='кол-во клиентов');
print("Распределение по активности:\n", data.groupby('IsActiveMember')['CustomerId'].count())
# Out:
# Распределение по активности:
#  IsActiveMember
# 0    4849
# 1    5151
# Name: CustomerId, dtype: int64

# %% [markdown]
# **Выводы по графику:**
# * общее распределение клиентов на "активных" и "пассивных" имеет достаточно равномерный характер
# * отток в группе "пассивных" клиентов в 2 раза выше, чем в группе "активных"

# %%
# изучаем распределение данных по признаку EstimatedSalary с разбивкой по целевой переменной
fig, axes = plt.subplots(1, 1, figsize=(15, 5))
g = sns.histplot(data=data, x="EstimatedSalary", hue="Exited", multiple="stack", bins=50)
g.set_title('Распределение данных по признаку EstimatedSalary с разбивкой по целевой переменной');

# %%
# выводим стат информацию
data['EstimatedSalary'].describe()
# Out:
# count     10000.000000
# mean     100090.239881
# std       57510.492818
# min          11.580000
# 25%       51002.110000
# 50%      100193.915000
# 75%      149388.247500
# max      199992.480000
# Name: EstimatedSalary, dtype: float64

# %% [markdown]
# **Выводы по данным и графику:**
# * данные имеют достаточно монотонное распределение в промежутке от 11 (практически 0) до 199 992 (практически 200 000)
# * доля оттока также выдерживается в рамках общего тренда
# * 25% клиентов имеют ожидаемую зарплату до 51 000
# * 50% клиентов - до 100 194
# * 75% клиентов - до 149 388

# %% [markdown]
# ### Подготовка признаков

# %%
# строим тепловую карту корреляции
plt.figure(figsize=(14, 5)) 
heatmap = sns.heatmap(data.corr(), annot=True, fmt='.2f', linewidths=.5, cmap="YlGnBu") 
heatmap.set_title('Тепловая карта корреляции', fontsize=12);

# %% [markdown]
# **Выводы по графику:**
# * признаки не имеют выраженной линейной зависимости

# %%
# удаляем признаки, очевидно не влияющие на отток
data_upgrade = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)
display(data_upgrade.head(2))
# Out:
#    CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0          619    France  Female   42     2.0      0.00              1
# 1          608     Spain  Female   41     1.0  83807.86              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0

# %% [markdown]
# **Признак Tenure:**
# * первичный анализ данных показал наличие 909 пропущенных значений (NaN) в объектах по признаку Tenure (*сколько лет человек является клиентом банка*)
# * анализ распределения имеющихся данных по этому признаку показал монотонность распределения в промежутке от 0 до 10
# * анализ пропущенных значений в объектах, сгруппированных по странам, гендеру и целевому признаку показал, что пропущенные значения распределены равномерно по гендеру и пропорционально (в соответствии с общим паттерном распределения) по стрнам и целевому признаку
# * анализ взаимосвязей между данными показал отсутствие возможности обеспечить логичное заполнение пропущенных данных
# * все остальные данные в объектах с пропущенными значениями Tenure присутствуют
# * в выборе между удалением 10% полноценных объектов и признаком принято решение удалить признак

# %%
# удаляем признак Tenure,
# проверяем оставшиеся признаки
data_upgrade = data_upgrade.drop('Tenure', axis=1)
display(data_upgrade.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Balance          10000 non-null  float64
#  5   NumOfProducts    10000 non-null  int64
#  6   HasCrCard        10000 non-null  int64
#  7   IsActiveMember   10000 non-null  int64
#  8   EstimatedSalary  10000 non-null  float64
#  9   Exited           10000 non-null  int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 781.4+ KB
# None

# %%
# производим кодирование признаков Geography и Gender методом унитарного кодирования
data_upgrade = pd.get_dummies(data_upgrade)
display(data_upgrade.info())
display(data_upgrade.Geography_France.value_counts())
display(data_upgrade.Gender_Male.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        10000 non-null  int64
#  1   Age                10000 non-null  int64
#  2   Balance            10000 non-null  float64
#  3   NumOfProducts      10000 non-null  int64
#  4   HasCrCard          10000 non-null  int64
#  5   IsActiveMember     10000 non-null  int64
#  6   EstimatedSalary    10000 non-null  float64
#  7   Exited             10000 non-null  int64
#  8   Geography_France   10000 non-null  uint8
#  9   Geography_Germany  10000 non-null  uint8
#  10  Geography_Spain    10000 non-null  uint8
#  11  Gender_Female      10000 non-null  uint8
#  12  Gender_Male        10000 non-null  uint8
# dtypes: float64(2), int64(6), uint8(5)
# memory usage: 674.0 KB
# None
# 1    5014
# 0    4986
# Name: Geography_France, dtype: int64
# 1    5457
# 0    4543
# ...

# %%
# проверяем важность признаков по модели Случайного леса с фокусом на метрику F1
# делим датасет на признаки и целевую переменную
X = data_upgrade.drop('Exited', axis=1)
y = data_upgrade.Exited
# определяем и обучаем модель
model = RandomForestClassifier(random_state=0)
model.fit(X, y)
# рассчитываем важность
results = permutation_importance(model, X, y, scoring='f1')
importance = results.importances_mean
importance=np.sort(importance)
# сводим результаты
for i,v in enumerate(importance):
    print('Feature: {}  Score: {}' .format(i,v))
# визуализируем сведенные результаты
plt.bar([x for x in range(len(importance))] ,importance)
plt.suptitle('Определение веса признака моделью Случайного леса')
plt.show()
# Out:
# Feature: 0  Score: 0.03630728338464388
# Feature: 1  Score: 0.08067751305150081
# Feature: 2  Score: 0.08152195004141236
# Feature: 3  Score: 0.08761381848742118
# Feature: 4  Score: 0.08761682399886843
# Feature: 5  Score: 0.14638843723280465
# Feature: 6  Score: 0.19130321358122765
# Feature: 7  Score: 0.20088609129205065
# Feature: 8  Score: 0.23978078637397804
# Feature: 9  Score: 0.2861854578776611
# Feature: 10  Score: 0.31545638131524806
# Feature: 11  Score: 0.5085259971442948

# %%
# проверяем попарное распределение данных в параметрах с разбивкой по целевой перменной
g = sns.pairplot(data=data_upgrade, hue='Exited')
g.fig.suptitle('Попарное рапределение данных параметров с разбивкой по целевой перменной'\
               , y=1.08, fontsize=18);

# %% [markdown]
# **Выводы по графику:**
# * финальная матрица попарного распределения признаков не выявила трендов или паттернов, отличных от описанных в EDA

# %% [markdown]
# ### Разделение данных на выборки

# %%
# делим данные на признаки (матрица X) и целевую переменную (y)
# проверяем количество измерений 
X = data_upgrade.drop('Exited', axis=1)
y = data_upgrade['Exited']
print(X.shape)
print(y.shape)
# Out:
# (10000, 12)
# (10000,)

# %%
# разделяем данные на обучающую и тестовую выборки в пропорции 60х40
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, stratify = y, random_state=0
)

# %%
# проверяем количество измерений в выборках
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6000, 12)
# (6000,)
# (4000, 12)
# (4000,)

# %%
# разделяем данные тестовой выборки на валидационную и тестовую выборки в пропорции 50х50
X_valid, X_test, y_valid, y_test = train_test_split(
    X_test, y_test, test_size=0.5, stratify = y_test, random_state=0
)

# %%
# проверяем количество измерений в выборках
print(X_valid.shape)
print(y_valid.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2000, 12)
# (2000,)
# (2000, 12)
# (2000,)

# %%
# проверяем равномерность распределения данных по классам в выборках
print(f"Количество строк в y_train по классам: {np.bincount(y_train)}")
print(f"Количество строк в y_valid по классам: {np.bincount(y_valid)}")
print(f"Количество строк в y_test по классам: {np.bincount(y_test)}")
# Out:
# Количество строк в y_train по классам: [4778 1222]
# Количество строк в y_valid по классам: [1592  408]
# Количество строк в y_test по классам: [1593  407]

# %%
# стандартизируем данные
# обучаем StandartScaler на обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train)

# преобразуем обучающий, валидационный и тестовый наборы данных
X_train_st = scaler.transform(X_train)
X_valid_st = scaler.transform(X_valid)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# #### Выводы:
# * датасет разделен на матрицу признаков (X) и целевую переменную (y)
# * данные разделены на обучающую, валидационную и тестовую выборки в пропорции 60х20х20
# * равномерность распределения данных по классам в выборках соблюдена
# * обучающий, валидационный и тестовый наборы данных стандартизированы

# %% [markdown]
# ### Исследование моделей

# %% [markdown]
# #### Дерево решений

# %%
# подбираем лучший гиперпараметр  max_depth с RandomizedSearchCV,
# выбираем метрику настройки F1
max_depth = range(1, 50)
hyperparameters = dict(max_depth=max_depth)
DecisionTree = DecisionTreeClassifier(random_state = 0)

randomizedsearch = RandomizedSearchCV(DecisionTree, hyperparameters, random_state = 0, scoring='f1')
dt_best_model_random = randomizedsearch.fit(X_train_st, y_train)
print(dt_best_model_random.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=8, random_state=0)

# %%
# делаем прогноз с лучшей моделью
dt_model = DecisionTreeClassifier(random_state=0, max_depth=8)
dt_model.fit(X_train_st, y_train)
dt_predictions_valid = dt_model.predict(X_valid_st)

# %%
# выводим метрики для полученного прогноза по лучшей модели дерева решений
print('Метрики при автоматическом прогнозе на валидационной выборке по модели дерева решений')
print('F1: {:.2f}'.format(f1_score(y_valid, dt_predictions_valid)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_valid, dt_predictions_valid)))
print('RECALL: {:.2f}'.format(recall_score(y_valid, dt_predictions_valid)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели дерева решений
# F1: 0.57
# ROC_AUC: 0.71
# RECALL: 0.48

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_valid,dt_predictions_valid)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# **Выводы по данным и графику:**
# * модель слабо справляется с определением положительного класса (TP)

# %%
# строим график ROC curve
probabilities_valid = dt_model.predict_proba(X_valid_st)
probabilities_one_valid = probabilities_valid[:, 1]
 
fpr, tpr, thresholds = roc_curve(y_valid, probabilities_one_valid)
 
plt.figure()
plt.plot(fpr, tpr, label = 'ROC кривая')

plt.plot([0, 1], [0, 1], linestyle='--', label = 'Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC кривая Дерево решений')
plt.legend()
plt.show()

# %% [markdown]
# #### Случайный лес

# %%
# подбираем лучшие гиперпараметры  n_estimators, max_depth, min_samples_leaf с RandomizedSearchCV,
# выбираем метрику настройки F1
n_estimators = range(1, 100)
max_depth = range(1,50)
min_samples_leaf = range(1,13)

hyperparameters = dict( max_depth=max_depth, min_samples_leaf = min_samples_leaf, n_estimators = n_estimators)
RandomForest = RandomForestClassifier(random_state = 0)

randomizedsearch = RandomizedSearchCV(RandomForest, hyperparameters, random_state = 0, scoring='f1')
rf_best_model_random = randomizedsearch.fit(X_train_st, y_train)
print(rf_best_model_random.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=45, min_samples_leaf=2, n_estimators=46,
#                        random_state=0)

# %%
# делаем прогноз с лучшей моделью
rf_model = RandomForestClassifier(random_state=0, n_estimators=46, max_depth=45, min_samples_leaf = 2)
rf_model.fit(X_train_st, y_train)
rf_predictions_valid = rf_model.predict(X_valid_st)

# %%
# выводим метрики для полученного прогноза по модели случайного леса
print('Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса')
print('F1: {:.2f}'.format(f1_score(y_valid, rf_predictions_valid)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_valid, rf_predictions_valid)))
print('RECALL: {:.2f}'.format(recall_score(y_valid, rf_predictions_valid)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса
# F1: 0.58
# ROC_AUC: 0.72
# RECALL: 0.47

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_valid,rf_predictions_valid)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# **Выводы по данным и графику:**
# * модель слабо справляется с определением положительного класса (TP)

# %%
# строим график ROC curve
probabilities_valid = rf_model.predict_proba(X_valid_st)
probabilities_one_valid = probabilities_valid[:, 1]
 
fpr, tpr, thresholds = roc_curve(y_valid, probabilities_one_valid)
 
plt.figure()
plt.plot(fpr, tpr, label = 'ROC кривая')

plt.plot([0, 1], [0, 1], linestyle='--', label = 'Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC кривая Случайный лес')
plt.legend()
plt.show()

# %% [markdown]
# #### Выводы:
# * для решения задачи классификации в ходе исследования были протестированы 2 модели на валидационной выборке:
# >
# > Дерево решений
# >
# > Случайный лес
#
# * **Дерево решений** - с помощью RandomizedSearchCV проработан гиперпараметр глубины дерева; наилучший результат на валидационной выборке показала **глубина =8** со следующими результатами по метрикам:
# 1. F1: 0.57
# 2. ROC_AUC: 0.71
# 3. RECALL: 0.48
# 4. TP = 195 predictions
# * **Случайный лес** - с помощью RandomizedSearchCV проработаны гиперпараметры количества деревьев, глубины дерева и минимального количества выборок; наилучший результат на валидационной выборке показало **количество деревьев = 46, глубины дерева = 45, количества выборок = 2** со следующими результатами по метрикам:
# 1. F1: 0.58
# 2. ROC_AUC: 0.72
# 3. RECALL: 0.47
# 4. TP = 191 predictions
# * дисбаланс классов определил низкие показатели метрик полноты и F1

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# ### Настройка гиперпараметра class_weight = 'balanced'

# %% [markdown]
# #### Дерево решений

# %%
# делаем прогноз с лучшей моделью
dt_model_bal = DecisionTreeClassifier(random_state=0, max_depth=8, class_weight = 'balanced')
dt_model_bal.fit(X_train_st, y_train)
dt_predictions_bal_valid = dt_model_bal.predict(X_valid_st)

# %%
# выводим метрики для полученного прогноза по лучшей модели дерева решений
print('Метрики при автоматическом прогнозе на валидационной выборке по модели дерева решений')
print('F1: {:.2f}'.format(f1_score(y_valid, dt_predictions_bal_valid)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_valid, dt_predictions_bal_valid)))
print('RECALL: {:.2f}'.format(recall_score(y_valid, dt_predictions_bal_valid)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели дерева решений
# F1: 0.55
# ROC_AUC: 0.74
# RECALL: 0.71

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_valid,dt_predictions_bal_valid)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# #### Случайный лес

# %%
# делаем прогноз с лучшей моделью
rf_model_bal = RandomForestClassifier(random_state=0, n_estimators=46, max_depth=45, min_samples_leaf = 2\
                                      , class_weight='balanced')
rf_model_bal.fit(X_train_st, y_train)
rf_predictions_bal_valid = rf_model_bal.predict(X_valid_st)

# %%
# выводим метрики для полученного прогноза по модели случайного леса
print('Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса')
print('F1: {:.2f}'.format(f1_score(y_valid, rf_predictions_bal_valid)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_valid, rf_predictions_bal_valid)))
print('RECALL: {:.2f}'.format(recall_score(y_valid, rf_predictions_bal_valid)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса
# F1: 0.62
# ROC_AUC: 0.75
# RECALL: 0.57

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_valid,rf_predictions_bal_valid)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# ### Увеличение обучающей выборки

# %%
# создаем функцию для увеличения обучающей выборки по положительному классу
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    features_upsampled, target_upsampled = shuffle(
    features_upsampled, target_upsampled, random_state=12345)
    return features_upsampled, target_upsampled

# %%
# увеличиваем обучающую выборку по положительному классу в 3 раза
X_train_up, y_train_up = upsample(X_train, y_train, 3)
print(X_train_up.shape)
print(y_train_up.shape)
# Out:
# (8444, 12)
# (8444,)

# %%
# проверяем равномерность распределения данных у увеличенной обучающей выборки по классам
print(f"Количество строк в y_train_up по классам: {np.bincount(y_train_up)}")
# Out:
# Количество строк в y_train_up по классам: [4778 3666]

# %%
# стандартизируем данные увеличенной обучающей выборки
# обучаем StandartScaler на увеличенной обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train_up)

# преобразуем обучающий, валидационный и тестовый наборы данных
X_train_up_st = scaler.transform(X_train_up)

# %% [markdown]
# #### Дерево принятия решений - увеличенная обучающая выборка

# %%
# подбираем лучший гиперпараметр  max_depth с RandomizedSearchCV
max_depth = range(1, 100)
hyperparameters = dict(max_depth=max_depth)

DecisionTree = DecisionTreeClassifier(random_state=0)

randomizedsearch = RandomizedSearchCV(DecisionTree, hyperparameters, random_state = 0, scoring='f1')
dt_best_model_random_up = randomizedsearch.fit(X_train_up_st, y_train_up)
print(dt_best_model_random_up.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=27, random_state=0)

# %%
# обучаем дерево решений на увеличенной обучающей выборке,
# делаем прогноз с лучшей моделью
dt_model_up = DecisionTreeClassifier(random_state=0, max_depth=27)
dt_model_up.fit(X_train_up_st, y_train_up)
dt_predictions_valid_up = dt_model_up.predict(X_valid_st)

# %%
# выводим метрики для полученного прогноза по модели дерева решений
print('Метрики при автоматическом прогнозе на валидационной выборке по модели дерева решений')
print('F1: {:.2f}'.format(f1_score(y_valid, dt_predictions_valid_up)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_valid, dt_predictions_valid_up)))
print('RECALL: {:.2f}'.format(recall_score(y_valid, dt_predictions_valid_up)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели дерева решений
# F1: 0.52
# ROC_AUC: 0.70
# RECALL: 0.55

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_valid,dt_predictions_valid_up)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# #### Случайный лес - увеличенная обучающая выборка

# %%
# подбираем лучшие гиперпараметры  n_estimators, max_depth, min_samples_leaf с RandomizedSearchCV
# для увеличенной обучающей выборки
n_estimators = range(1, 100)
max_depth = range(1,13)
min_samples_leaf = range(1,13)

hyperparameters = dict( max_depth=max_depth, min_samples_leaf = min_samples_leaf, n_estimators = n_estimators,)

RandomForest = RandomForestClassifier(random_state = 0)

randomizedsearch = RandomizedSearchCV(RandomForest, hyperparameters, scoring = 'f1', random_state = 0)
rf_best_model_random = randomizedsearch.fit(X_train_up_st, y_train_up)
print(rf_best_model_random.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=12, n_estimators=56, random_state=0)

# %%
# делаем прогноз с лучшей моделью на увеличенной выборке
rf_model_up = RandomForestClassifier(random_state=0, n_estimators=14, max_depth=11, min_samples_leaf = 3)
rf_model_up.fit(X_train_up_st, y_train_up)
rf_predictions_valid_up = rf_model_up.predict(X_valid_st)

# %%
# выводим метрики для полученного прогноза по модели случайного леса
print('Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса')
print('F1: {:.2f}'.format(f1_score(y_valid, rf_predictions_valid_up)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_valid, rf_predictions_valid_up)))
print('RECALL: {:.2f}'.format(recall_score(y_valid, rf_predictions_valid_up)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса
# F1: 0.61
# ROC_AUC: 0.76
# RECALL: 0.65

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_valid,rf_predictions_valid_up)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# #### Выводы
# * для борьбы с дисбалансом были применены в подхода:
# >
# > настройка гиперпараметра class_weight = 'balanced'
# >
# > использование функции увеличения обучающей выборки по положительному классу
# >
# * **class_weight = 'balanced'** - по метрикам F1 и ROC_AUC победила модель Случайного леса; Дерево решений показало хороший результат по метрике RECALL и хорошо предсказало истинно полижительный класс
# * **увеличение выборки** - опытным путем было установлено наиболее продуктивное увеличение в 3 раза
# * модель **Дерева решений** с увеличенной обучающей выборкой показала на валидационной выборке худшие результаты по метрикам F1 и ROC_AUC
# * модель **Случайного леса** с увеличенной обучающей выборкой показала на валидационной выборке ухудшение результата по метрике F1, но улучшение по метрикам  ROC_AUC и RECALL
# * для работы с тестовой выборкой выбираем лучшую модель **Случайного леса** с обычной обучающей выборкой и с использованием гиперпараметра class_weight = 'balanced'

# %%
# делаем сводную таблицу результатов исследования
results_valid = pd.DataFrame(columns=(['model', 'disbal_appr', 'f1', 'roc_auc', 'recall', 'tp']))
results_valid.model = ['dt', 'dt', 'dt', 'rf', 'rf', 'rf']
results_valid.disbal_appr = ['none', 'class_bal', 'sample_up', 'none', 'class_bal', 'sample_up']
results_valid.f1 = [0.57, 0.55, 0.52, 0.58, 0.62, 0.61]
results_valid.roc_auc = [0.71, 0.74, 0.70, 0.72, 0.75, 0.76]
results_valid.recall = [0.48, 0.71, 0.55, 0.47, 0.57, 0.65]
results_valid.tp = [195, 290, 224, 191, 231,266]

# %% [markdown]
# **Результаты исследования моделей на валидационной выборке:**

# %%
cm = sns.light_palette("blue", as_cmap=True)
display(results_valid.style.background_gradient(cmap=cm))
# Out:
# <style  type="text/css" >
# #T_fe89e_row0_col2{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_fe89e_row0_col3{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_fe89e_row0_col4,#T_fe89e_row0_col5{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_fe89e_row1_col2{
#             background-color:  #a9a9f6;
#             color:  #000000;
#         }#T_fe89e_row1_col3{
#             background-color:  #5050fb;
#             color:  #f1f1f1;
#         }#T_fe89e_row1_col4,#T_fe89e_row1_col5,#T_fe89e_row4_col2,#T_fe89e_row5_col3{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_fe89e_row2_col2,#T_fe89e_row2_col3,#T_fe89e_row3_col4,#T_fe89e_row3_col5{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_fe89e_row2_col4,#T_fe89e_row2_col5,#T_fe89e_row3_col3{
#             background-color:  #a0a0f7;
# ...

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# **Обучающая выборка**

# %%
# делаем прогноз для тестовой выборки с лучшей моделью случайного леса и гиперпараметром class_weight
rf_model_test = RandomForestClassifier(random_state=0, n_estimators=46, max_depth=45, min_samples_leaf = 2\
                               , class_weight='balanced')
rf_model_test.fit(X_train_st, y_train)
rf_predictions_test = rf_model_test.predict(X_test_st)

# %%
# выводим метрики для полученного прогноза по модели случайного леса
print('Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса')
print('F1: {:.2f}'.format(f1_score(y_test, rf_predictions_test)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_test, rf_predictions_test)))
print('RECALL: {:.2f}'.format(recall_score(y_test, rf_predictions_test)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса
# F1: 0.61
# ROC_AUC: 0.74
# RECALL: 0.54

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_test,rf_predictions_test)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# **Объединенная обучающая выборка**

# %%
# объединяем обучающую и валидационную выборки
X_train_united = X_train.append(X_valid, ignore_index=True)
X_train_united.shape
# Out:
# (8000, 12)

# %%
# объединяем обучающую и валидационную целевые переменные
y_train_united = y_train.append(y_valid, ignore_index=True)
y_train_united.shape
# Out:
# (8000,)

# %%
# перемешиваем значения
X_train_united, y_train_united = shuffle(
    X_train_united, y_train_united, random_state=0)

# %%
# проверяем равномерность распределения данных у объединенной обучающей выборки по классам
print(f"Количество строк в y_train_united по классам: {np.bincount(y_train_united)}")
# Out:
# Количество строк в y_train_united по классам: [6370 1630]

# %%
# стандартизируем данные
# обучаем StandartScaler на объединенной обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train_united)

# преобразуем объединенный обучающий набор данных
X_train_united_st = scaler.transform(X_train_united)

# %%
# подбираем лучшие гиперпараметры  n_estimators, max_depth, min_samples_leaf с RandomizedSearchCV
# для объединенной обучающей выборки
n_estimators = range(1, 100)
max_depth = range(1,13)
min_samples_leaf = range(1,13)

hyperparameters = dict( max_depth=max_depth, min_samples_leaf = min_samples_leaf, n_estimators = n_estimators,)

RandomForest = RandomForestClassifier(random_state = 0)

randomizedsearch = RandomizedSearchCV(RandomForest, hyperparameters, scoring = 'f1')
rf_best_model_united_random = randomizedsearch.fit(X_train_united_st, y_train_united)
print(rf_best_model_united_random.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=12, min_samples_leaf=2, n_estimators=27,
#                        random_state=0)

# %%
# делаем прогноз для тестовой выборки с лучшей моделью случайного леса и гиперпараметром class_weight,
# обученной на объедененной обучающей выборке
rf_model_united_test = RandomForestClassifier(random_state=0, n_estimators=96, max_depth=11\
                                              , min_samples_leaf = 3, class_weight='balanced')
rf_model_united_test.fit(X_train_united_st, y_train_united)
rf_predictions_united_test = rf_model_united_test.predict(X_test_st)

# %%
# выводим метрики для полученного прогноза по модели случайного леса
print('Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса')
print('F1: {:.2f}'.format(f1_score(y_test, rf_predictions_united_test)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_test, rf_predictions_united_test)))
print('RECALL: {:.2f}'.format(recall_score(y_test, rf_predictions_united_test)))
# Out:
# Метрики при автоматическом прогнозе на валидационной выборке по модели случайного леса
# F1: 0.65
# ROC_AUC: 0.78
# RECALL: 0.66

# %%
# выводим матрицу ответов
cm=confusion_matrix(y_test,rf_predictions_united_test)
plt.figure(figsize=(10,5))
plt.title('Матрица ответов')
sns.heatmap(cm, annot=True,fmt='d', cmap="YlGnBu")
plt.ylabel('Фактические значения')
plt.xlabel('Предсказанные значения');

# %% [markdown]
# ### Выводы
# * лучшие результаты на тестовой выборке показала модель **Случайного леса**, обученная на восстановленной (train + valid) выборке с подобранными гиперпараметрами: **max_depth=11, min_samples_leaf=3, n_estimators=96, random_state=0**
# >
# > F1: 0.65
# >
# > ROC_AUC: 0.78
# >
# > RECALL: 0.66
# >
# * для проверки весь цикл обучения по всем моделям также был проведен на датасете с сохраненным параметром Tenure, но удаленными объектами с отсутствующими по этому параметру данными; эксперимент не дал улучшения результата
# * в борьбе с дисбалансом классов по целевой переменной оказалось достаточно настроить гиперпараметр class_weight='balanced'
# * поставленная в проекте задача:"Постройте модель с предельно большим значением F1-меры", достигнута с помощью модели **Случайного леса** с настроенными гиперпараметрами:**max_depth=11, min_samples_leaf=3, n_estimators=96, random_state=0**
# * метрика ROC_AUC выбранной модели показала результат 0.78, что свидетельствует об устойчивой предсказательной мощности модели на данном датасете
# * модель корректно предсказала 66% объектов положительного класса
